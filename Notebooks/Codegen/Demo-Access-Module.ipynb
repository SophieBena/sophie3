# %% [markdown]
# # Demonstrates access to a coder generated module
# ## (1) cd to the working directory
# where the pyx, pyxbuild and C/C++ files are located that were generated by a coder notebook

# %%
# %cd working

# %% [markdown]
# ## (2) Use pyximport to read the pyx files
# in order to perform a Cython build

# %%
import pyximport
pyximport.install()

# %% [markdown]
# ## (3) Import the desired module

# %%
import berman

# %%
# %cd ..

# %% [markdown]
# ## (4) Examine the methods available in the imported module

# %%
help (berman)

# %% [markdown]
# ## (5) Execute a function in the module

# %%
berman.cy_Potassium_Feldspar_berman_calib_identifier()

# %%
berman.cy_Potassium_Feldspar_berman_calib_g(1000,1000)
